# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName("DataFrame").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/12/11 23:22:34 WARN Utils: Your hostname, DESKTOP-O3JU6DO, resolves to a loopback address: 127.0.1.1; using 172.25.43.62 instead (on interface eth0)
# 25/12/11 23:22:34 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/11 23:22:37 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/12/11 23:22:38 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://172.25.43.62:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>DataFrame</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
## read the dataset
df=spark.read.csv("test_2.csv",header=True, inferSchema=True)
df.show()
# Out:
# +-----+---+----------+
# | Name|Age|Experience|
# +-----+---+----------+
# |Rahul| 21|         2|
# | Ravi| 22|         3|
# |Rayan| 23|         3|
# |  Rio| 34|         5|
# +-----+---+----------+

# %%
## check the Schema
df.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)

# %%
df.select("Name")
# Out:
# DataFrame[Name: string]

# %%
df.select("Name").show()
# Out:
# +-----+
# | Name|
# +-----+
# |Rahul|
# | Ravi|
# |Rayan|
# |  Rio|
# +-----+

# %%
df.select(["Name","Experience"]).show()
# Out:
# +-----+----------+
# | Name|Experience|
# +-----+----------+
# |Rahul|         2|
# | Ravi|         3|
# |Rayan|         3|
# |  Rio|         5|
# +-----+----------+

# %%
df.dtypes
# Out:
# [('Name', 'string'), ('Age', 'int'), ('Experience', 'int')]

# %%
df.describe()
# Out:
# DataFrame[summary: string, Name: string, Age: string, Experience: string]

# %%
df.describe().show()
# Out:
# [Stage 12:>                                                         (0 + 1) / 1]
# +-------+-----+------------------+------------------+
# |summary| Name|               Age|        Experience|
# +-------+-----+------------------+------------------+
# |  count|    4|                 4|                 4|
# |   mean| NULL|              25.0|              3.25|
# | stddev| NULL|6.0553007081949835|1.2583057392117918|
# |    min|Rahul|                21|                 2|
# |    max|  Rio|                34|                 5|
# +-------+-----+------------------+------------------+

# %%
## Adding the columns to DataFrame
df.withColumn('Experience after 2 years',df['Experience']+2).show()
# Out:
# +-----+---+----------+------------------------+
# | Name|Age|Experience|Experience after 2 years|
# +-----+---+----------+------------------------+
# |Rahul| 21|         2|                       4|
# | Ravi| 22|         3|                       5|
# |Rayan| 23|         3|                       5|
# |  Rio| 34|         5|                       7|
# +-----+---+----------+------------------------+

# %%
## Dropping Columns from the DataFrame
df.drop('Experience').show()
# Out:
# +-----+---+
# | Name|Age|
# +-----+---+
# |Rahul| 21|
# | Ravi| 22|
# |Rayan| 23|
# |  Rio| 34|
# +-----+---+

# %%
## Renaming Columns
df.withColumnRenamed('Name','New Name').show()
# Out:
# +--------+---+----------+
# |New Name|Age|Experience|
# +--------+---+----------+
# |   Rahul| 21|         2|
# |    Ravi| 22|         3|
# |   Rayan| 23|         3|
# |     Rio| 34|         5|
# +--------+---+----------+
